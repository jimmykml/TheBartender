# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dotenv import load_dotenv
import os
import sys 

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
load_dotenv()  # Loads .env file containing OPENAI_API_KEY
assert "OPENAI_API_KEY" in os.environ, "Missing OPENAI_API_KEY in environment."

# %%
from models.openai_model import OpenAIModel

llm = OpenAIModel(model="gpt-3.5-turbo")  # or gpt-3.5-turbo for cheaper/faster tests

# 📌 Step 4: Run a test prompt
prompt = "Summarize the latest trends in the stock market in 2 sentences."

response = llm.generate(prompt)

# 📌 Step 5: Display result
print("🧠 LLM Response:")
print(response)
# Out:
# 🧠 LLM Response:
# The stock market has been experiencing increased volatility due to concerns over inflation, interest rates, and the ongoing pandemic. Tech stocks have been particularly affected, while sectors such as energy and financials have shown resilience.
